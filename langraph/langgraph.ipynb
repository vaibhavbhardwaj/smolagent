# %%
from langgraph.graph import StateGraph, END
import random
from typing import Dict, List, TypedDict

# %%
class GameState(TypedDict):
    player_name: str
    target_number: int
    guesses: List[int]
    attempts: int
    hint: str
    lower_bound: int 
    upper_bound: int

# %%
def setup_node(state: GameState) -> GameState:
    """Initialize the game with a random target number"""
    state["player_name"] = f"Welcome, {state['player_name']}!"
    state["target_number"] = random.randint(1, 20)
    state["guesses"] = []
    state["attempts"] = 0
    state["hint"] = "Game started! Try to guess the number."
    state["lower_bound"] = 1 
    state["upper_bound"] = 20 
    print(f"{state['player_name']} The game has begun. I'm thinking of a number between 1 and 20.")
    return state

def guess_node(state: GameState)->GameState:
   
    possible_guesses = [i for i in range(state["lower_bound"], state["upper_bound"] + 1) if i not in state["guesses"]]
    if possible_guesses:
        guess = random.choice(possible_guesses)
    else:        
        guess = random.randint(state["lower_bound"], state["upper_bound"])
    print("---",guess)
    state["guesses"].append(guess)
    state["attempts"] += 1
    print(f"Attempt {state['attempts']}: Guessing {guess} (Current range: {state['lower_bound']}-{state['upper_bound']})")
    return state

def hint_node(state: GameState) -> GameState:
    """Here we provide a hint based on the last guess and update the bounds"""
    print(state)
    latest_guess = state["guesses"][-1]
    print(latest_guess,state["target_number"])
    target = state["target_number"]
    print(latest_guess,target)
    if latest_guess < target:
        state["hint"] = f"The number {latest_guess} is too low. Try higher!"
        
        state["lower_bound"] = max(state["lower_bound"], latest_guess + 1)
        print(f"Hint: {state['hint']}")
        
    elif latest_guess > target:
        state["hint"] = f"The number {latest_guess} is too high. Try lower!"
      
        state["upper_bound"] = min(state["upper_bound"], latest_guess - 1)
        print(f"Hint: {state['hint']}")
    else:
        state["hint"] = f"Correct! You found the number {target} in {state['attempts']} attempts."
        print(f"Success! {state['hint']}")
    
    return state
    
def should_continue(state: GameState) -> str:
    """Determine if we should continue guessing or end the game"""
    
    # There are 2 end conditions - either 7 is reached or the correct number is guessed
    
    latest_guess = state["guesses"][-1]
    if latest_guess == state["target_number"]:
        print(f"GAME OVER: Number found!")
        return "end"
    elif state["attempts"] >= 7:
        print(f"GAME OVER: Maximum attempts reached! The number was {state['target_number']}")
        return "end"
    else:
        print(f"CONTINUING: {state['attempts']}/7 attempts used")
        return "continue"

# %%
graph = StateGraph(GameState)
graph.add_node("setup",setup_node)
graph.add_node("guess",guess_node)
graph.add_edge("setup","guess")
graph.add_node("hint_node",hint_node)
graph.add_edge("guess","hint_node")
graph.add_conditional_edges(
    "hint_node",
    should_continue,{
        "continue":"guess",
        "end":END
    }
)
graph.set_entry_point("setup")
app = graph.compile()
result = app.invoke({"player_name": "Student", "guesses": [], "attempts": 0, "lower_bound": 1, "upper_bound": 20})
# Out:
# Welcome, Student! The game has begun. I'm thinking of a number between 1 and 20.
# --- 20
# Attempt 1: Guessing 20 (Current range: 1-20)
# {'player_name': 'Welcome, Student!', 'target_number': 6, 'guesses': [20], 'attempts': 1, 'hint': 'Game started! Try to guess the number.', 'lower_bound': 1, 'upper_bound': 20}
# 20 6
# 20 6
# Hint: The number 20 is too high. Try lower!
# CONTINUING: 1/7 attempts used
# --- 14
# Attempt 2: Guessing 14 (Current range: 1-19)
# {'player_name': 'Welcome, Student!', 'target_number': 6, 'guesses': [20, 14], 'attempts': 2, 'hint': 'The number 20 is too high. Try lower!', 'lower_bound': 1, 'upper_bound': 19}
# 14 6
# 14 6
# Hint: The number 14 is too high. Try lower!
# CONTINUING: 2/7 attempts used
# --- 10
# Attempt 3: Guessing 10 (Current range: 1-13)
# {'player_name': 'Welcome, Student!', 'target_number': 6, 'guesses': [20, 14, 10], 'attempts': 3, 'hint': 'The number 14 is too high. Try lower!', 'lower_bound': 1, 'upper_bound': 13}
# 10 6
# 10 6
# Hint: The number 10 is too high. Try lower!
# CONTINUING: 3/7 attempts used
# --- 3
# Attempt 4: Guessing 3 (Current range: 1-9)
# {'player_name': 'Welcome, Student!', 'target_number': 6, 'guesses': [20, 14, 10, 3], 'attempts': 4, 'hint': 'The number 10 is too high. Try lower!', 'lower_bound': 1, 'upper_bound': 9}
# 3 6
# 3 6
# Hint: The number 3 is too low. Try higher!
# CONTINUING: 4/7 attempts used
# --- 4
# Attempt 5: Guessing 4 (Current range: 4-9)
# {'player_name': 'Welcome, Student!', 'target_number': 6, 'guesses': [20, 14, 10, 3, 4], 'attempts': 5, 'hint': 'The number 3 is too low. Try higher!', 'lower_bound': 4, 'upper_bound': 9}
# 4 6
# 4 6
# Hint: The number 4 is too low. Try higher!
# CONTINUING: 5/7 attempts used
# --- 8
# Attempt 6: Guessing 8 (Current range: 5-9)
# {'player_name': 'Welcome, Student!', 'target_number': 6, 'guesses': [20, 14, 10, 3, 4, 8], 'attempts': 6, 'hint': 'The number 4 is too low. Try higher!', 'lower_bound': 5, 'upper_bound': 9}
# 8 6
# 8 6
# Hint: The number 8 is too high. Try lower!
# CONTINUING: 6/7 attempts used
# --- 7
# Attempt 7: Guessing 7 (Current range: 5-7)
# {'player_name': 'Welcome, Student!', 'target_number': 6, 'guesses': [20, 14, 10, 3, 4, 8, 7], 'attempts': 7, 'hint': 'The number 8 is too high. Try lower!', 'lower_bound': 5, 'upper_bound': 7}
# 7 6
# 7 6
# Hint: The number 7 is too high. Try lower!
# GAME OVER: Maximum attempts reached! The number was 6
